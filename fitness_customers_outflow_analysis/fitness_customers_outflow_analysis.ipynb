# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-0.0.0.1"><span class="toc-item-num">0.0.0.1&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span><ul class="toc-item"><li><span><a href="#Контекст-проекта" data-toc-modified-id="Контекст-проекта-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Контекст проекта</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Цели-проекта" data-toc-modified-id="Цели-проекта-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Цели проекта</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Проведение-исследовательского-анализа-данных" data-toc-modified-id="Проведение-исследовательского-анализа-данных-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Проведение исследовательского анализа данных</a></span><ul class="toc-item"><li><span><a href="#Посмотреть-на-датасет:-есть-ли-в-нём-отсутствующие-значения-(пропуски),-изучить-средние-значения-и-стандартные-отклонения-(пригодится-метод-describe());" data-toc-modified-id="Посмотреть-на-датасет:-есть-ли-в-нём-отсутствующие-значения-(пропуски),-изучить-средние-значения-и-стандартные-отклонения-(пригодится-метод-describe());-1.3.2.1"><span class="toc-item-num">1.3.2.1&nbsp;&nbsp;</span>Посмотреть на датасет: есть ли в нём отсутствующие значения (пропуски), изучить средние значения и стандартные отклонения (пригодится метод describe());</a></span></li><li><span><a href="#Посмотреть-на-средние-значения-признаков-в-двух-группах-—-тех,-кто-ушел-в-отток-и-тех,-кто-остался-(воспользуйтесь-методом-groupby());" data-toc-modified-id="Посмотреть-на-средние-значения-признаков-в-двух-группах-—-тех,-кто-ушел-в-отток-и-тех,-кто-остался-(воспользуйтесь-методом-groupby());-1.3.2.2"><span class="toc-item-num">1.3.2.2&nbsp;&nbsp;</span>Посмотреть на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуйтесь методом groupby());</a></span></li><li><span><a href="#Построить-столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток);" data-toc-modified-id="Построить-столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток);-1.3.2.3"><span class="toc-item-num">1.3.2.3&nbsp;&nbsp;</span>Построить столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);</a></span></li><li><span><a href="#Построить-матрицу-корреляций-и-отобразите-её." data-toc-modified-id="Построить-матрицу-корреляций-и-отобразите-её.-1.3.2.4"><span class="toc-item-num">1.3.2.4&nbsp;&nbsp;</span>Построить матрицу корреляций и отобразите её.</a></span></li></ul></li><li><span><a href="#Построить-модель-прогнозирования-оттока-клиентов" data-toc-modified-id="Построить-модель-прогнозирования-оттока-клиентов-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Построить модель прогнозирования оттока клиентов</a></span></li><li><span><a href="#Сделать-кластеризацию-клиентов" data-toc-modified-id="Сделать-кластеризацию-клиентов-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Сделать кластеризацию клиентов</a></span><ul class="toc-item"><li><span><a href="#Стандартизивать-данные." data-toc-modified-id="Стандартизивать-данные.-1.3.4.1"><span class="toc-item-num">1.3.4.1&nbsp;&nbsp;</span>Стандартизивать данные.</a></span></li><li><span><a href="#Построить-матрицу-расстояний-функцией-linkage()-на-стандартизованной-матрице-признаков-и-нарисовать-дендрограмму.----Внимание:-отрисовка-дендрограммы-может-занять-время!-На-основании-полученного-графика-предположите,-какое-количество-кластеров-можно-выделить." data-toc-modified-id="Построить-матрицу-расстояний-функцией-linkage()-на-стандартизованной-матрице-признаков-и-нарисовать-дендрограмму.----Внимание:-отрисовка-дендрограммы-может-занять-время!-На-основании-полученного-графика-предположите,-какое-количество-кластеров-можно-выделить.-1.3.4.2"><span class="toc-item-num">1.3.4.2&nbsp;&nbsp;</span>Построить матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисовать дендрограмму.    Внимание: отрисовка дендрограммы может занять время! На основании полученного графика предположите, какое количество кластеров можно выделить.</a></span></li><li><span><a href="#Обучить-модель-кластеризации-на-основании-алгоритма-K-Means-и-спрогнозировать-кластеры-клиентов.-Договоримся-за-число-кластеров-принять-n=5,-чтобы--результаты-можно-было-сравнивать-с-результатами-остальных-студентов." data-toc-modified-id="Обучить-модель-кластеризации-на-основании-алгоритма-K-Means-и-спрогнозировать-кластеры-клиентов.-Договоримся-за-число-кластеров-принять-n=5,-чтобы--результаты-можно-было-сравнивать-с-результатами-остальных-студентов.-1.3.4.3"><span class="toc-item-num">1.3.4.3&nbsp;&nbsp;</span>Обучить модель кластеризации на основании алгоритма K-Means и спрогнозировать кластеры клиентов. Договоримся за число кластеров принять n=5, чтобы  результаты можно было сравнивать с результатами остальных студентов.</a></span></li><li><span><a href="#Посмотреть-на-средние-значения-признаков-для-кластеров.-Можно-ли-сразу-что-то-заметить?" data-toc-modified-id="Посмотреть-на-средние-значения-признаков-для-кластеров.-Можно-ли-сразу-что-то-заметить?-1.3.4.4"><span class="toc-item-num">1.3.4.4&nbsp;&nbsp;</span>Посмотреть на средние значения признаков для кластеров. Можно ли сразу что-то заметить?</a></span></li><li><span><a href="#Построить-распределения-признаков-для-кластеров.-Можно-ли-что-то-заметить-по-ним?" data-toc-modified-id="Построить-распределения-признаков-для-кластеров.-Можно-ли-что-то-заметить-по-ним?-1.3.4.5"><span class="toc-item-num">1.3.4.5&nbsp;&nbsp;</span>Построить распределения признаков для кластеров. Можно ли что-то заметить по ним?</a></span></li><li><span><a href="#Для-каждого-полученного-кластера-посчитать-долю-оттока-(методом-groupby()).-Отличаются-ли-они-по-доле-оттока?-Какие-кластеры-склонны-к-оттоку,-а-какие-—-надёжны?" data-toc-modified-id="Для-каждого-полученного-кластера-посчитать-долю-оттока-(методом-groupby()).-Отличаются-ли-они-по-доле-оттока?-Какие-кластеры-склонны-к-оттоку,-а-какие-—-надёжны?-1.3.4.6"><span class="toc-item-num">1.3.4.6&nbsp;&nbsp;</span>Для каждого полученного кластера посчитать долю оттока (методом groupby()). Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?</a></span></li></ul></li><li><span><a href="#Сформулировать-выводы-и-сделать-базовые-рекомендации-по-работе-с-клиентами" data-toc-modified-id="Сформулировать-выводы-и-сделать-базовые-рекомендации-по-работе-с-клиентами-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>Сформулировать выводы и сделать базовые рекомендации по работе с клиентами</a></span></li></ul></li></ul></li><li><span><a href="#Загрузка-библиотек-и-данных" data-toc-modified-id="Загрузка-библиотек-и-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузка библиотек и данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-библиотек" data-toc-modified-id="Загрузка-библиотек-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Загрузка библиотек</a></span></li><li><span><a href="#Открытие-файла-данных" data-toc-modified-id="Открытие-файла-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Открытие файла данных</a></span></li></ul></li><li><span><a href="#Проведение-исследовательского-анализа-данных" data-toc-modified-id="Проведение-исследовательского-анализа-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Проведение исследовательского анализа данных</a></span><ul class="toc-item"><li><span><a href="#Посмотреть-на-датасет:-есть-ли-в-нём-отсутствующие-значения-(пропуски),-изучить-средние-значения-и-стандартные-отклонения-(пригодится-метод-describe())" data-toc-modified-id="Посмотреть-на-датасет:-есть-ли-в-нём-отсутствующие-значения-(пропуски),-изучить-средние-значения-и-стандартные-отклонения-(пригодится-метод-describe())-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Посмотреть на датасет: есть ли в нём отсутствующие значения (пропуски), изучить средние значения и стандартные отклонения (пригодится метод describe())</a></span></li><li><span><a href="#Посмотреть-на-средние-значения-признаков-в-двух-группах-—-тех,-кто-ушел-в-отток-и-тех,-кто-остался-(воспользуйтесь-методом-groupby())" data-toc-modified-id="Посмотреть-на-средние-значения-признаков-в-двух-группах-—-тех,-кто-ушел-в-отток-и-тех,-кто-остался-(воспользуйтесь-методом-groupby())-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Посмотреть на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуйтесь методом groupby())</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-3.2.0.1"><span class="toc-item-num">3.2.0.1&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li></ul></li></ul></li><li><span><a href="#Построить-столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток);" data-toc-modified-id="Построить-столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток);-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Построить столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);</a></span></li><li><span><a href="#Построить-матрицу-корреляций-и-отобразите-её." data-toc-modified-id="Построить-матрицу-корреляций-и-отобразите-её.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Построить матрицу корреляций и отобразите её.</a></span></li></ul></li><li><span><a href="#Построить-модель-прогнозирования-оттока-клиентов" data-toc-modified-id="Построить-модель-прогнозирования-оттока-клиентов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Построить модель прогнозирования оттока клиентов</a></span></li><li><span><a href="#Сделать-кластеризацию-клиентов" data-toc-modified-id="Сделать-кластеризацию-клиентов-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Сделать кластеризацию клиентов</a></span><ul class="toc-item"><li><span><a href="#Стандартизуем-данные" data-toc-modified-id="Стандартизуем-данные-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Стандартизуем данные</a></span></li><li><span><a href="#Построим-матрицу-расстояний-функцией-linkage()-на-стандартизованной-матрице-признаков-и-нарисовать-дендрограмму.-Внимание:-отрисовка-дендрограммы-может-занять-время!-На-основании-полученного-графика-предположите,-какое-количество-кластеров-можно-выделить." data-toc-modified-id="Построим-матрицу-расстояний-функцией-linkage()-на-стандартизованной-матрице-признаков-и-нарисовать-дендрограмму.-Внимание:-отрисовка-дендрограммы-может-занять-время!-На-основании-полученного-графика-предположите,-какое-количество-кластеров-можно-выделить.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Построим матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисовать дендрограмму. Внимание: отрисовка дендрограммы может занять время! На основании полученного графика предположите, какое количество кластеров можно выделить.</a></span></li><li><span><a href="#Обучим-модель-кластеризации-на-основании-алгоритма-K-Means-и-спрогнозировать-кластеры-клиентов.-Договоримся-за-число-кластеров-принять-n=5,-чтобы-результаты-можно-было-сравнивать-с-результатами-остальных-студентов." data-toc-modified-id="Обучим-модель-кластеризации-на-основании-алгоритма-K-Means-и-спрогнозировать-кластеры-клиентов.-Договоримся-за-число-кластеров-принять-n=5,-чтобы-результаты-можно-было-сравнивать-с-результатами-остальных-студентов.-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Обучим модель кластеризации на основании алгоритма K-Means и спрогнозировать кластеры клиентов. Договоримся за число кластеров принять n=5, чтобы результаты можно было сравнивать с результатами остальных студентов.</a></span></li><li><span><a href="#Посмотрим-на-средние-значения-признаков-для-кластеров.-Можно-ли-сразу-что-то-заметить?" data-toc-modified-id="Посмотрим-на-средние-значения-признаков-для-кластеров.-Можно-ли-сразу-что-то-заметить?-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Посмотрим на средние значения признаков для кластеров. Можно ли сразу что-то заметить?</a></span></li><li><span><a href="#Построить-распределения-признаков-для-кластеров.-Можно-ли-что-то-заметить-по-ним?" data-toc-modified-id="Построить-распределения-признаков-для-кластеров.-Можно-ли-что-то-заметить-по-ним?-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Построить распределения признаков для кластеров. Можно ли что-то заметить по ним?</a></span></li><li><span><a href="#Для-каждого-полученного-кластера-посчитаем-долю-оттока-(методом-groupby()).-Отличаются-ли-они-по-доле-оттока?-Какие-кластеры-склонны-к-оттоку,-а-какие-—-надёжны?" data-toc-modified-id="Для-каждого-полученного-кластера-посчитаем-долю-оттока-(методом-groupby()).-Отличаются-ли-они-по-доле-оттока?-Какие-кластеры-склонны-к-оттоку,-а-какие-—-надёжны?-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Для каждого полученного кластера посчитаем долю оттока (методом groupby()). Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?</a></span></li></ul></li><li><span><a href="#Выводы-и-рекомендации" data-toc-modified-id="Выводы-и-рекомендации-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы и рекомендации</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Выводы</a></span></li><li><span><a href="#Ключевой-вывод" data-toc-modified-id="Ключевой-вывод-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Ключевой вывод</a></span></li><li><span><a href="#Рекомендации-маркетологам" data-toc-modified-id="Рекомендации-маркетологам-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Рекомендации маркетологам</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-6.3.0.1"><span class="toc-item-num">6.3.0.1&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# ### Контекст проекта

# %% [markdown]
# Сеть фитнес-центров «Культурист-датасаентист» разрабатывает стратегию взаимодействия с клиентами на основе аналитических данных.
# Необходимо оценить отток клиентов. Как понять, что клиент больше не с нами? Можно записать в отток тех, кто попросил закрыть договор или удалил аккаунт. Однако клиенты не всегда уходят демонстративно: чаще перестают пользоваться сервисом тихо.
# Индикаторы оттока зависят от специфики отрасли. Для фитнес-центра можно считать, что клиент попал в отток, если за последний месяц ни разу не посетил спортзал. Конечно, не исключено, что он уехал на Бали и по приезде обязательно продолжит ходить на фитнес. Однако чаще бывает наоборот. Если клиент начал новую жизнь с понедельника, немного походил в спортзал, а потом пропал — скорее всего, он не вернётся.
# Чтобы бороться с оттоком, отдел по работе с клиентами «Культуриста-датасаентиста» перевёл в электронный вид множество клиентских анкет.
#
# Моя задача — провести анализ и подготовить план действий по удержанию клиентов.
# А именно:
# 1. Научиться прогнозировать вероятность оттока (на уровне следующего месяца) для каждого клиента;
# 2. Сформировать типичные портреты клиентов: выделить несколько наиболее ярких групп и охарактеризовать их основные свойства;
# 3. Проанализировать основные признаки, наиболее сильно влияющие на отток;
# 4. Сформулировать основные выводы и разработать рекомендации по повышению качества работы с клиентами:
#    - выделить целевые группы клиентов;
#    - предложить меры по снижению оттока;
#    - определить другие особенности взаимодействия с клиентами.

# %% [markdown]
# ### Описание данных

# %% [markdown]
# «Культурист-датасаентист» предоставил сведения в csv-файлах. Заказчик подготовил данные, которые содержат данные на месяц до оттока и факт оттока на определённый месяц. Набор данных включает следующие поля:
# 1. Данные клиента за предыдущий до проверки факта оттока месяц:
#    - 'gender' — пол;
#    - 'Near_Location' — проживание или работа в районе, где находится фитнес-центр;
#    - 'Partner' — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента);
#    - Promo_friends — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента);
#    - 'Phone' — наличие контактного телефона;
#    - 'Age' — возраст;
#    - 'Lifetime' — время с момента первого обращения в фитнес-центр (в месяцах).
# 2. Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
#    - 'Contract_period' — длительность текущего действующего абонемента (месяц, 6 месяцев, год);
#    - 'Month_to_end_contract' — срок до окончания текущего действующего абонемента (в месяцах);
#    - 'Group_visits' — факт посещения групповых занятий;
#    - 'Avg_class_frequency_total' — средняя частота посещений в неделю за все время с начала действия абонемента;
#    - 'Avg_class_frequency_current_month' — средняя частота посещений в неделю за предыдущий месяц;
#    - 'Avg_additional_charges_total' — суммарная выручка от других услуг фитнес-центра: кафе, спорттовары, косметический и массажный салон.
#    - 'Churn' — факт оттока в текущем месяце.

# %% [markdown]
# ### Цели проекта

# %% [markdown]
# #### Загрузка данных

# %% [markdown]
# Путь к файлу:.

# %% [markdown]
# #### Проведение исследовательского анализа данных

# %% [markdown]
# ##### Посмотреть на датасет: есть ли в нём отсутствующие значения (пропуски), изучить средние значения и стандартные отклонения (пригодится метод describe());

# %% [markdown]
# ##### Посмотреть на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуйтесь методом groupby());

# %% [markdown]
# ##### Построить столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);

# %% [markdown]
# ##### Построить матрицу корреляций и отобразите её.

# %% [markdown]
# #### Построить модель прогнозирования оттока клиентов

# %% [markdown]
# Построить модель бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце:
# - Разбить данные на обучающую и валидационную выборку функцией train_test_split().
# - Обучить модель на train-выборке двумя способами:
#    - логистической регрессией,
#    - случайным лесом.
# - Оценить метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравните по ним модели. Какая модель показала себя лучше на основании метрик?
#
# Не забыть указать параметр random_state при разделении выборки и задании алгоритма.

# %% [markdown]
# #### Сделать кластеризацию клиентов

# %% [markdown]
# Отложите в сторону столбец с оттоком и проведите кластеризацию объектов (клиентов):

# %% [markdown]
# ##### Стандартизивать данные.

# %% [markdown]
# ##### Построить матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисовать дендрограмму.    Внимание: отрисовка дендрограммы может занять время! На основании полученного графика предположите, какое количество кластеров можно выделить.

# %% [markdown]
# ##### Обучить модель кластеризации на основании алгоритма K-Means и спрогнозировать кластеры клиентов. Договоримся за число кластеров принять n=5, чтобы  результаты можно было сравнивать с результатами остальных студентов.

# %% [markdown]
# ##### Посмотреть на средние значения признаков для кластеров. Можно ли сразу что-то заметить?

# %% [markdown]
# ##### Построить распределения признаков для кластеров. Можно ли что-то заметить по ним?

# %% [markdown]
# ##### Для каждого полученного кластера посчитать долю оттока (методом groupby()). Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?

# %% [markdown]
# #### Сформулировать выводы и сделать базовые рекомендации по работе с клиентами

# %% [markdown]
# - Сформулировать основные выводы и предложить рекомендации для стратегии взаимодействия с клиентами и их удержания.
# - Не описывать стратегию детально: достаточно 3-4 важных принципов и примеров их реализации в виде определённых маркетинговых действий.

# %% [markdown]
# ## Загрузка библиотек и данных

# %% [markdown]
# ### Загрузка библиотек

# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.tree import DecisionTreeClassifier
from scipy.cluster.hierarchy import dendrogram, linkage

# %% [markdown]
# ### Открытие файла данных

# %%
try:
    data = pd.read_csv('')
except:
    print ("Какая то ошибка")

# %%
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %% [markdown]
# Очевидных пропусков в файлах данных не видно.

# %% [markdown]
# В одном из первых блоков курса обучения нам говорили, что хорошим стилем являются имена переменных в "змеином регистре". Поэтому и для удобства дальнейшей работы переименуем столбцы.

# %%
data = data.rename(
                   columns={'Near_Location':'near_location', 'Partner':'partner', 'Promo_friends':'promo_friends',
                            'Phone':'phone', 'Contract_period':'contract_period', 'Group_visits':'group_visits', 'Age':'age',
                           'Avg_additional_charges_total':'avg_additional_charges_total', 'Month_to_end_contract':'month_to_end_contract',
                            'Lifetime':'lifetime', 'Avg_class_frequency_total':'avg_class_frequency_total',
                            'Avg_class_frequency_current_month':'avg_class_frequency_current_month', 'Churn':'churn',} 
                  )
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   near_location                      4000 non-null   int64
#  2   partner                            4000 non-null   int64
#  3   promo_friends                      4000 non-null   int64
#  4   phone                              4000 non-null   int64
#  5   contract_period                    4000 non-null   int64
#  6   group_visits                       4000 non-null   int64
#  7   age                                4000 non-null   int64
#  8   avg_additional_charges_total       4000 non-null   float64
#  9   month_to_end_contract              4000 non-null   float64
#  10  lifetime                           4000 non-null   int64
# ...

# %% [markdown]
# ## Проведение исследовательского анализа данных

# %% [markdown]
# ### Посмотреть на датасет: есть ли в нём отсутствующие значения (пропуски), изучить средние значения и стандартные отклонения (пригодится метод describe())

# %%
data.describe()
# Out:
#             gender  near_location      partner  promo_friends        phone  \
# count  4000.000000    4000.000000  4000.000000    4000.000000  4000.000000
# mean      0.510250       0.845250     0.486750       0.308500     0.903500
# std       0.499957       0.361711     0.499887       0.461932     0.295313
# min       0.000000       0.000000     0.000000       0.000000     0.000000
# 25%       0.000000       1.000000     0.000000       0.000000     1.000000
# 50%       1.000000       1.000000     0.000000       0.000000     1.000000
# 75%       1.000000       1.000000     1.000000       1.000000     1.000000
# max       1.000000       1.000000     1.000000       1.000000     1.000000
#
#        contract_period  group_visits          age  \
# count      4000.000000   4000.000000  4000.000000
# mean          4.681250      0.412250    29.184250
# std           4.549706      0.492301     3.258367
# min           1.000000      0.000000    18.000000
# ...

# %% [markdown]
# В нашем датасете 4000 наблюдений, 13 признаков, целевая переменная 'churn'. Катеригиональные признаки уже приведены к числовому типу. Среди них только те, которые могут принимать два значения (даже гендеров к счастью исследователя в России все еще только два официально)

# %% [markdown]
# Аномальных значений не видно. Возраст от 18 до 41, время от первого обращения от 0 до 31 месяца (для старожилов клуба). Даже максимальная средняя частота посещений в неделю 6 раз вопросов не вызывает (энтузиасты), минимальная 0 тоже (купили абонемент, но не ходят).

# %%
print ('ГИСТОГРАММЫ РАСПРЕДЕЛЕНИЯ ПРИЗНАКОВ')
f, axes = plt.subplots(nrows=4, ncols=4, figsize=(24,24), dpi=90)
 
features = list(set(data.columns[:-1]))
for idx, feat in  enumerate(features):
    sns.histplot(x=feat, data=data, ax=axes[idx // 4, idx % 4]).set(title='Признак ' + feat)
    axes[idx // 4, idx % 4].set_ylabel('')
    axes[idx // 4, idx % 4].set_xlabel('');
# Out:
# ГИСТОГРАММЫ РАСПРЕДЕЛЕНИЯ ПРИЗНАКОВ

# %% [markdown]
# Приведенные выше диаграммы подтверждают отсутствие аномальных значений

# %% [markdown]
# Проверим датасет на наличие дубликатов

# %%
print ('Дубликатов в таблице:', data.duplicated().sum())
# Out:
# Дубликатов в таблице: 0

# %% [markdown]
# Дубликатов нет.

# %% [markdown]
# ### Посмотреть на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуйтесь методом groupby())

# %%
data_gr=data.groupby(['churn'], as_index = False).agg({'age': 'count'})
data_gr
# Out:
#    churn   age
# 0      0  2939
# 1      1  1061

# %% [markdown]
# Видим, что в оттоке 1061 заказачик, осталось 2939. Разница чуть меньше, чем в три раза. Промежуточно можно отметить, что если эта цифра перекрывается среднемесячной продажей новых контрактов, то результат довольно неплохой. Около 25% потерь ежемесячно

# %%
data_gr_mean = data.groupby('churn', as_index = False).mean()
display(data_gr_mean)
# Out:
#    churn    gender  near_location   partner  promo_friends     phone  \
# 0      0  0.510037       0.873086  0.534195       0.353522  0.903709
# 1      1  0.510839       0.768143  0.355325       0.183789  0.902922
#
#    contract_period  group_visits        age  avg_additional_charges_total  \
# 0         5.747193      0.464103  29.976523                    158.445715
# 1         1.728558      0.268615  26.989632                    115.082899
#
#    month_to_end_contract  lifetime  avg_class_frequency_total  \
# 0               5.283089  4.711807                   2.024876
# 1               1.662582  0.990575                   1.474995
#
#    avg_class_frequency_current_month
# 0                           2.027882
# 1                           1.044546

# %% [markdown]
# Отметим, что средние значения всех признаков (за исключение пола, близости расположения, наличия телефона, возраста), для тех, кто не ушел в отток, гораздо выше.

# %% [markdown]
# ### Построить столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);

# %%
print ('ГИСТОГРАММЫ РАСПРЕДЕЛЕНИЯ ПРИЗНАКОВ ДЛЯ ТЕХ, КТО УШЁЛ (ОТТОК) И ТЕХ, КТО ОСТАЛСЯ (НЕ ПОПАЛИ В ОТТОК)')
f, axes = plt.subplots(nrows=4, ncols=4, figsize=(24,24), dpi=90)
 
features = list(set(data.columns[:-1]))
for idx, feat in  enumerate(features):
    sns.histplot(x=feat, hue = 'churn', data=data, ax=axes[idx // 4, idx % 4]).set(title='Признак ' + feat)
    axes[idx // 4, idx % 4].set_ylabel('')
    axes[idx // 4, idx % 4].set_xlabel('');
# Out:
# ГИСТОГРАММЫ РАСПРЕДЕЛЕНИЯ ПРИЗНАКОВ ДЛЯ ТЕХ, КТО УШЁЛ (ОТТОК) И ТЕХ, КТО ОСТАЛСЯ (НЕ ПОПАЛИ В ОТТОК)

# %% [markdown]
# В результате анализа полученных гистограмм мы уже можем сделать некоторые выводы:
# 1. Среди ушедших будет больше доля тех, кто посещает клуб реже.
# 2. Более молодые заказчики явно проявляют большую склонность к тому, чтобы попасть в отток.
# 3. Попадающие в отток меньше тратят дополнительно.
# 4. В оттоке преобладают более короткие контракты.

# %% [markdown]
# ### Построить матрицу корреляций и отобразите её.

# %%
cm = data.corr()
print (cm)
# Out:
#                                      gender  near_location   partner  \
# gender                             1.000000       0.006699 -0.010463
# near_location                      0.006699       1.000000 -0.005119
# partner                           -0.010463      -0.005119  1.000000
# promo_friends                     -0.005033       0.210964  0.451960
# phone                             -0.008542      -0.015763  0.009970
# contract_period                    0.000502       0.150233  0.306166
# group_visits                       0.017879       0.154728  0.022710
# age                                0.013807       0.058358  0.047480
# avg_additional_charges_total      -0.009334       0.040761  0.022941
# month_to_end_contract             -0.001281       0.143961  0.294632
# lifetime                           0.013579       0.070921  0.061229
# avg_class_frequency_total          0.014620       0.043127  0.024938
# avg_class_frequency_current_month  0.009156       0.062664  0.045561
# ...

# %%
plt.figure(figsize = (16,10))

sns.heatmap(cm, annot = True, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm', linewidths=3,
            linecolor='black').set(title = 'Корреляция признаков в нашем датасете')
plt.show()

# %% [markdown]
# Видим сильную корреляцию между двумя парами признаков:
# 1. 'month_to_end_contract' и 'contract_period' (оставить стоит именно его, так как он чуть сильнее влияет на целевую переменную) - 0,97
# 2. 'avg_class_frequency_total' и 'avg_class_frequency_current_month'(оставь нужно именно его, т.к. он сильнее влият на целевую переменную) - 0,95
# 3. На целевую переменную сильнее всего влияют: 'avg_class_frequency_current_month', 'lifetime', 'age', 'contract_period' (признаки, которые стоит удалить не включил).

# %% [markdown]
# Удалим столбцы 'month_to_end_contract' и 'avg_class_frequency_total'

# %%
data_m=data.drop(columns = ['month_to_end_contract', 'avg_class_frequency_total'], axis = 1)
data_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   near_location                      4000 non-null   int64
#  2   partner                            4000 non-null   int64
#  3   promo_friends                      4000 non-null   int64
#  4   phone                              4000 non-null   int64
#  5   contract_period                    4000 non-null   int64
#  6   group_visits                       4000 non-null   int64
#  7   age                                4000 non-null   int64
#  8   avg_additional_charges_total       4000 non-null   float64
#  9   lifetime                           4000 non-null   int64
#  10  avg_class_frequency_current_month  4000 non-null   float64
# ...

# %% [markdown]
# Далее будем работать с датафреймом data_m

# %% [markdown]
# ## Построить модель прогнозирования оттока клиентов

# %% [markdown]
# Построим модель бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце:
#    - Разобъем данные на обучающую и валидационную выборку функцией train_test_split().
#    - Обучим модель на train-выборке двумя способами:
#         - логистической регрессией,
#         - случайным лесом.
#    - Оценим метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравним по ним модели. Какая модель показала себя лучше на основании метрик?
#
# Не забудем указать параметр random_state при разделении выборки и задании алгоритма.

# %%
y = data_m['churn']
X = data_m.drop(['churn'], axis=1)

# %% [markdown]
# Разбиваем данные на обучающую и валидационную выборки

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# Обучаем модель на  train-выборке логистической регрессией

# %%
#обучим  «стандартизатор» на обучающей выборке
scaler = StandardScaler()
scaler.fit(X_train)
#применим «стандартизатор» для тестовой и обучающией выборки
X_train_st = scaler.transform(X_train)
X_test_st = scaler.transform(X_test)
#X_train_st = X_train
#X_test_st = X_test

# %%
print('Гистограмма целевой переменной на test и train выборках')
sns.kdeplot(y_train)
sns.kdeplot(y_test)
plt.show()
# Out:
# Гистограмма целевой переменной на test и train выборках

# %% [markdown]
# Видим, что распределения максимально схожи.

# %%
lr_model = LogisticRegression(solver='liblinear', random_state=0)
lr_model.fit(X_train_st, y_train)
# Out:
# LogisticRegression(random_state=0, solver='liblinear')

# %%
probabilities_lr = lr_model.predict_proba(X_test_st)[:, 1]
predictions_lr = lr_model.predict(X_test_st)

print('Accuracy: {:.4f}'.format(accuracy_score(y_test, predictions_lr)))
print('Precision: {:.4f}'.format(precision_score(y_test, predictions_lr)))
print('Recall: {:.4f}'.format(recall_score(y_test, predictions_lr)))
print('F1: {:.4f}'.format(f1_score(y_test, predictions_lr)))
print('ROC_AUC: {:.4f}'.format(roc_auc_score(y_test, predictions_lr)))
# Out:
# Accuracy: 0.9025
# Precision: 0.7913
# Recall: 0.8232
# F1: 0.8069
# ROC_AUC: 0.8759

# %% [markdown]
# Обучаем модель на  train-выборке случайным лесом

# %%
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 0)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
probabilities_rf = rf_model.predict_proba(X_test)[:, 1]
predictions_rf = rf_model.predict(X_test)
print('Accuracy: {:.4f}'.format(accuracy_score(y_test, predictions_rf)))
print('Precision: {:.4f}'.format(precision_score(y_test, predictions_rf)))
print('Recall: {:.4f}'.format(recall_score(y_test, predictions_rf)))
print('F1: {:.4f}'.format(f1_score(y_test, predictions_rf)))
print('ROC_AUC: {:.4f}'.format(roc_auc_score(y_test, predictions_rf)))
# Out:
# Accuracy: 0.8962
# Precision: 0.8142
# Recall: 0.7525
# F1: 0.7822
# ROC_AUC: 0.8480

# %% [markdown]
# Промежуточный вывод:
# 1. В целом результаты полученные по обеим моделям сравнимы, если судить только по меркам accuracy, precision и recall (как в задании. Чуть выше Accuracy и Recall у LogisticRegression. Но по Precision впереди RandomForestClassifier
# 2. Для верности добавим метрики F1 и ROC_AUC. И по обеим лучший результат у LogisticRegression
# 3. На основании метрик лучше себя показала модель LogisticRegression.

# %% [markdown]
# ## Сделать кластеризацию клиентов

# %% [markdown]
# ### Стандартизуем данные

# %%
scaler = StandardScaler() # создаём объект класса scaler (нормализатор)
x_sc = scaler.fit_transform(data_m.drop(columns = ['churn'])) # обучаем нормализатор и преобразуем набор данных 
print(x_sc[:10])
# Out:
# [[ 0.97970588  0.42788074  1.02686062  1.49716101 -3.05985201  0.28989014
#    1.19403206 -0.0565538  -1.37753121 -0.19332863 -1.67847198]
#  [-1.0207145   0.42788074 -0.973842   -0.66793083  0.32681319  1.60882159
#    1.19403206  0.55732732 -0.35021325  0.87368001  0.1360137 ]
#  [-1.0207145   0.42788074  1.02686062 -0.66793083  0.32681319 -0.8092194
#   -0.83749845 -0.36349436 -0.1815923  -0.46008079 -0.02901851]
#  [-1.0207145   0.42788074  1.02686062  1.49716101  0.32681319  1.60882159
#    1.19403206  1.17120844 -0.87472237 -0.46008079  1.51045005]
#  [ 0.97970588  0.42788074  1.02686062  1.49716101  0.32681319 -0.8092194
#   -0.83749845 -0.97737548  0.5336998  -0.19332863 -0.61454183]
#  [ 0.97970588  0.42788074 -0.973842   -0.66793083  0.32681319 -0.8092194
#    1.19403206  1.478149    3.15330097 -0.19332863  0.82634551]
#  [ 0.97970588  0.42788074  1.02686062  1.49716101 -3.05985201  0.28989014
#    1.19403206  0.86426788 -0.54676556 -0.46008079 -0.46525669]
# ...

# %% [markdown]
# ### Построим матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисовать дендрограмму. Внимание: отрисовка дендрограммы может занять время! На основании полученного графика предположите, какое количество кластеров можно выделить.

# %%
linked = linkage(x_sc, method = 'ward') 
plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')
plt.title('Дендрограмма для фитнесс клуба')
plt.show()

# %% [markdown]
# На полученной дендрограмме 4 разных цвета. По идее рекомендовано 4 кластера.

# %% [markdown]
# ### Обучим модель кластеризации на основании алгоритма K-Means и спрогнозировать кластеры клиентов. Договоримся за число кластеров принять n=5, чтобы результаты можно было сравнивать с результатами остальных студентов.

# %%
km = KMeans(n_clusters=5, random_state=0) # задаём число кластеров, равное 5, и фиксируем значение random_state для воспроизводимости результата
labels = km.fit_predict(x_sc)
data_m['cluster'] = labels
data_m.info()
data_m.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   near_location                      4000 non-null   int64
#  2   partner                            4000 non-null   int64
#  3   promo_friends                      4000 non-null   int64
#  4   phone                              4000 non-null   int64
#  5   contract_period                    4000 non-null   int64
#  6   group_visits                       4000 non-null   int64
#  7   age                                4000 non-null   int64
#  8   avg_additional_charges_total       4000 non-null   float64
#  9   lifetime                           4000 non-null   int64
#  10  avg_class_frequency_current_month  4000 non-null   float64
# ...

# %% [markdown]
# ### Посмотрим на средние значения признаков для кластеров. Можно ли сразу что-то заметить?

# %%
data_cm = data_m.groupby('cluster', as_index = False).agg({'gender': 'mean', 'near_location': 'mean',
                                                          'partner': 'mean', 'promo_friends': 'mean',
                                                          'phone': 'mean', 'contract_period': 'mean',
                                                          'group_visits': 'mean', 'age': 'mean',
                                                          'avg_additional_charges_total': 'mean', 'lifetime': 'mean',
                                                          'avg_class_frequency_current_month': 'mean', 'churn': 'mean'
                                                          })
print(data_cm)
# Out:
#    cluster    gender  near_location   partner  promo_friends  phone  \
# 0        0  0.496447       0.995939  0.892386       1.000000      1
# 1        1  0.500000       0.000000  0.489247       0.078853      1
# 2        2  0.500940       1.000000  0.217105       0.072368      1
# 3        3  0.534260       0.996028  0.379345       0.009930      1
# 4        4  0.523316       0.862694  0.471503       0.305699      0
#
#    contract_period  group_visits        age  avg_additional_charges_total  \
# 0         6.922843      0.524873  29.606091                    153.424651
# 1         2.994624      0.232975  28.679211                    137.125763
# 2         2.010338      0.277256  27.583647                    119.339956
# 3         6.208540      0.538232  30.699106                    176.259567
# 4         4.777202      0.427461  29.297927                    144.208179
#
#    lifetime  avg_class_frequency_current_month     churn
# ...

# %% [markdown]
# Глядя на 11 признаков в 5 кластерах довольно сложно выявить четкие закономерности. Однако, поскольку это прямо прописано в ТЗ на проект попробуем:
# 1. В кластере 4 ни у кого нет контактных телефонов. В остальных кластерах у всех есть.
# 2. В кластере 0 все клиенты первоначально записались по акции "приведи друга".
# 3. В кластере 1 нет ни одного заказчика живущего близко к фитнесс центру.
# 4. В кластере 2 все клиенты проживают рядом с фитнесс-центром, самый короткий контракт, самые низкие дополнительные расходы, самый маленький контрактный период.
# 5. В кластере 3 самая высокая средня частота посещений, самые высокие дополнительные расходы, практически нет никого, кто пришел по акции "приведи друга".
# 6. Признаки гендера и возраста мало отличаются по кластерам.

# %% [markdown]
# ### Построить распределения признаков для кластеров. Можно ли что-то заметить по ним?

# %%
features_m = list(set(data_m.columns[:-1]))
print(features_m)
# Out:
# ['near_location', 'group_visits', 'avg_class_frequency_current_month', 'lifetime', 'phone', 'contract_period', 'age', 'partner', 'churn', 'gender', 'avg_additional_charges_total', 'promo_friends']

# %%
f, axes = plt.subplots(nrows=6, ncols=2, figsize=(24,48), dpi=90)
 

for idx, feat in  enumerate(features_m):
    sns.histplot( x=feat, data=data_m, hue='cluster',palette=sns.color_palette("hls",5), bins=10, multiple='stack', ax=axes[idx // 2, idx % 2]).set(title='Признак ' + feat)
    axes[idx // 2, idx % 2].set_ylabel('')
    axes[idx // 2, idx % 2].set_xlabel('');

# %% [markdown]
# Для визуализации  распределения признаков для кластеров мы можем использовать метод pairplot, но чтобы уменьшить размерность матрицы, мы избавимся от части столбцов, где либо нет зависимостей от кластеров, либо средние значения близки к  0 или 1. Это столбцы: gender, near_location, promo_friends, phone, age

# %%
data_cml = data_m.groupby('cluster', as_index = False).mean()
print(data_cml)
# Out:
#    cluster    gender  near_location   partner  promo_friends  phone  \
# 0        0  0.496447       0.995939  0.892386       1.000000    1.0
# 1        1  0.500000       0.000000  0.489247       0.078853    1.0
# 2        2  0.500940       1.000000  0.217105       0.072368    1.0
# 3        3  0.534260       0.996028  0.379345       0.009930    1.0
# 4        4  0.523316       0.862694  0.471503       0.305699    0.0
#
#    contract_period  group_visits        age  avg_additional_charges_total  \
# 0         6.922843      0.524873  29.606091                    153.424651
# 1         2.994624      0.232975  28.679211                    137.125763
# 2         2.010338      0.277256  27.583647                    119.339956
# 3         6.208540      0.538232  30.699106                    176.259567
# 4         4.777202      0.427461  29.297927                    144.208179
#
#    lifetime  avg_class_frequency_current_month     churn
# ...

# %%
data_m_pair = data_m.drop(['gender', 'near_location', 'promo_friends', 'phone', 'age'], axis=1)

# %%
features_mp = list(set(data_m_pair.columns[:-1]))
print(features_mp)
# Out:
# ['group_visits', 'avg_class_frequency_current_month', 'lifetime', 'churn', 'contract_period', 'partner', 'avg_additional_charges_total']

# %%
f, axes = plt.subplots(nrows=4, ncols=2, figsize=(24,48), dpi=90)
 

for idx, feat in  enumerate(features_mp):
    sns.histplot( x=feat, data=data_m_pair, hue='cluster',palette=sns.color_palette("hls",5),
                 multiple='stack', bins=10, ax=axes[idx // 2, idx % 2]).set(title='Признак ' + feat)
    axes[idx // 2, idx % 2].set_ylabel('')
    axes[idx // 2, idx % 2].set_xlabel('');

# %% [markdown]
# Визуализация подтверждает сделанные нами при исследовании таблицы со средними значениями по кластерам:
# 1. В кластере 4 ни у кого нет контактных телефонов. В остальных кластерах у всех есть.
# 2. В кластере 0 все клиенты первоначально записались по акции "приведи друга".
# 3. В кластере 1 нет ни одного заказчика живущего близко к фитнесс центру.
# 4. В кластере 2 все клиенты проживают рядом с фитнесс-центром, самый короткий контракт, самые низкие дополнительные расходы, самый маленький контрактный период.
# 5. В кластере 3 самая высокая средня частота посещений, самые высокие дополнительные расходы, практически нет никого, кто пришел по акции "приведи друга".
# 6. Признаки гендера и возраста мало отличаются по кластерам.

# %% [markdown]
# ### Для каждого полученного кластера посчитаем долю оттока (методом groupby()). Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?

# %%
data_churn = data_m.groupby(by=['cluster'])['churn'].agg(churn_cluster='sum', customer_cluster = 'count').reset_index()
data_churn
# Out:
#    cluster  churn_cluster  customer_cluster
# 0        0            118               985
# 1        1            225               558
# 2        2            600              1064
# 3        3             15              1007
# 4        4            103               386

# %%
data_churn['churn_share'] = data_churn['churn_cluster']/data_churn['customer_cluster']
data_churn
# Out:
#    cluster  churn_cluster  customer_cluster  churn_share
# 0        0            118               985     0.119797
# 1        1            225               558     0.403226
# 2        2            600              1064     0.563910
# 3        3             15              1007     0.014896
# 4        4            103               386     0.266839

# %% [markdown]
# Промежуточные выводы:
# 1. Самый низкий отток в кластере 3. Вообще по всем признакам (высокие допрасходы, частота посещений) это скорее всего сегмент постоянных клиентов клуба.
# 2. Также низкий отток в кластере 0. По этой акции, возможно приходят знакомые людей из кластера 3. И остаются.
# 3. Самый высокий отток в кластерах 2 и 1. В кластере 1 клиенты, живущие далек от клуба.
# 4. В кластере 2 все клиенты проживают рядом с фитнесс-центром, самый короткий контракт, самые низкие дополнительные расходы, самый маленький контрактный период.

# %% [markdown]
# ## Выводы и рекомендации

# %% [markdown]
# ### Выводы

# %% [markdown]
# 1. Размер исходного датафрейма 4000 строк в 12 столбцах.
# 2. Средние значения всех признаков (за исключение пола, близости расположения, наличия телефона, возраста), для тех, кто не ушел в отток, гораздо выше.
# 3. Построены модели оттока клиентов методами LogisticRegression и  RandomForestClassifier. Лучшие результаты показала модель LogisticRegression (Accuracy: 0.9025, Precision: 0.7913, Recall: 0.8232, F1: 0.8069, ROC_AUC: 0.8759)
# 4. Построена матрица расстояний функцией linkage() на стандартизованной матрице признаков и нарисована дендрограмма. Получено рекомендованное количество кластеров - 4.
# 5. Обучена модель кластеризации на основании алгоритма K-Means и спрогнозированы кластеры клиентов (5, в соответствии с ТЗ).
# 6. Проведено исследование средних значений. Замечено:
#     1. В кластере 4 ни у кого нет контактных телефонов. В остальных кластерах у всех есть.
#     2. В кластере 0 все клиенты первоначально записались по акции "приведи друга".
#     3. В кластере 1 нет ни одного заказчика живущего близко к фитнесс центру.
#     4. В кластере 2 все клиенты проживают рядом с фитнесс-центром, самый короткий контракт, самые низкие дополнительные расходы, самый маленький контрактный период.
#     5. В кластере 3 самая высокая средня частота посещений, самые высокие дополнительные расходы, практически нет никого, кто пришел по акции "приведи друга".
#     6. Признаки гендера и возраста мало отличаются по кластерам.
# 7. Построено распределение признаков для кластеров. Подтверждены выводы из пункта 5.
# 8. Проанализированы доли оттока по кластерам:
#     1. Самый низкий отток в кластере 3. Вообще по всем признакам (высокие допрасходы, частота посещений) это скорее всего сегмент постоянных клиентов клуба.
#     2. Также низкий отток в кластере 0. По этой акции, возможно приходят знакомые людей из кластера 3. И остаются.
#     3. Самый высокий отток в кластерах 2 и 1. В кластере 1 клиенты, живущие далек от клуба.
#     4. В кластере 2 все клиенты проживают рядом с фитнесс-центром, самый короткий контракт, самые низкие дополнительные расходы, самый маленький контрактный период.

# %% [markdown]
# ### Ключевой вывод

# %% [markdown]
# 1. Кластеры 0 и 3 схожи друг с другом по всем характеристикам. Отличие только в том, что в кластер 0 клиенты пришли по акции "приведи друга".
# 2. Кластер 1 - это заказчики, живущие далеко от фитнесс-центра, половина из которых пришло по партнерским программам.
# 3. Кластер 2 - это заказчики, рядом с фитнесс-центром, заключающие контракты на короткие сроки (начинают новую жизнь с понедельника, но бросают).
# 4. Кластер 4 - немногочисленный кластер "без телефонов" со средними по остальным признакам характеристиками.

# %% [markdown]
# ### Рекомендации маркетологам

# %% [markdown]
# 1. Сосредоточиться на работе с заказчиками из кластеров 1 и 2.
# 2. Для кластера 1:
#     1. Предложить программы по компенсации транспортных расходов.
#     2. Подготовить мероприятия, услуги, которые побуждали заказчика больше времени проводить в клубе (кафе (либо скидки в кафе рядом), салоны красоты (либо скидки в заведениях рядом)).
#     3. Дополнительные услуги в клубе с дополнительными скидками.
#     4. Предложить компаниям-партнерам возврат части оплаты (скидки), в случае если работник регулярно посещает клуб.
#
# 3. Для кластера 2:
#     1.  Прогрессивная скидка за более длинные контракты.
#     2.  Скидка за пролонгацию контракта.
#     3.  Наружная реклама в районе размещения фитнес-центра (напоминание, пробудить "совесть" или жадность(потратил, надо же ходить).
#     4.  Публичные мероприятия в районе размещения "клуба".
#     5.  Бесплатные услуги тренера при заключении контракта на более длинный период.
