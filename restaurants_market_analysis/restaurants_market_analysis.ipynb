# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-0.0.0.1"><span class="toc-item-num">0.0.0.1&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span><ul class="toc-item"><li><span><a href="#Контекст-проекта" data-toc-modified-id="Контекст-проекта-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Контекст проекта</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Цели-проекта" data-toc-modified-id="Цели-проекта-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Цели проекта</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-подготовка-к-анализу" data-toc-modified-id="Загрузка-данных-и-подготовка-к-анализу-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Загрузка данных и подготовка к анализу</a></span></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Анализ данных</a></span></li><li><span><a href="#Общие-выводы-и-рекомендации-о:" data-toc-modified-id="Общие-выводы-и-рекомендации-о:-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Общие выводы и рекомендации о:</a></span></li><li><span><a href="#Подготовка-презентации-для-инвестора" data-toc-modified-id="Подготовка-презентации-для-инвестора-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Подготовка презентации для инвестора</a></span></li></ul></li></ul></li><li><span><a href="#Загрузка-и-подготовка-данных" data-toc-modified-id="Загрузка-и-подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузка и подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек" data-toc-modified-id="Импорт-библиотек-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Импорт библиотек</a></span></li><li><span><a href="#Открытие-и-исследование-файлов-данных" data-toc-modified-id="Открытие-и-исследование-файлов-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Открытие и исследование файлов данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Исследование-соотношения-видов-объектов-общественного-питания-по-количеству." data-toc-modified-id="Исследование-соотношения-видов-объектов-общественного-питания-по-количеству.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Исследование соотношения видов объектов общественного питания по количеству.</a></span></li><li><span><a href="#Исследование-соотношения-сетевых-и-несетевых-заведений-по-количеству." data-toc-modified-id="Исследование-соотношения-сетевых-и-несетевых-заведений-по-количеству.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Исследование соотношения сетевых и несетевых заведений по количеству.</a></span></li><li><span><a href="#Определение-наиболее-распространенного-типа-сетевых-заведений" data-toc-modified-id="Определение-наиболее-распространенного-типа-сетевых-заведений-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Определение наиболее распространенного типа сетевых заведений</a></span></li><li><span><a href="#Что-характерно-для-сетевых-заведений:-много-заведений-с-небольшим-числом-посадочных-мест-в-каждом-или-мало-заведений-с-большим-количеством-посадочных-мест?" data-toc-modified-id="Что-характерно-для-сетевых-заведений:-много-заведений-с-небольшим-числом-посадочных-мест-в-каждом-или-мало-заведений-с-большим-количеством-посадочных-мест?-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Что характерно для сетевых заведений: много заведений с небольшим числом посадочных мест в каждом или мало заведений с большим количеством посадочных мест?</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-3.4.0.1"><span class="toc-item-num">3.4.0.1&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-3.4.0.2"><span class="toc-item-num">3.4.0.2&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li></ul></li></ul></li><li><span><a href="#Описание-среднего-количества-посадочных-мест-для-каждого-вида-объекта-общественного-питания.-Какой-вид-предоставляет-в-среднем-самое-большое-количество-посадочных-мест?" data-toc-modified-id="Описание-среднего-количества-посадочных-мест-для-каждого-вида-объекта-общественного-питания.-Какой-вид-предоставляет-в-среднем-самое-большое-количество-посадочных-мест?-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Описание среднего количества посадочных мест для каждого вида объекта общественного питания. Какой вид предоставляет в среднем самое большое количество посадочных мест?</a></span></li><li><span><a href="#Выделение-в-отдельный-столбец-информации-об-улице-из-столбца-address-." data-toc-modified-id="Выделение-в-отдельный-столбец-информации-об-улице-из-столбца-address-.-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Выделение в отдельный столбец информации об улице из столбца address .</a></span></li><li><span><a href="#Построение-график-топ-10-улиц-по-количеству-объектов-общественного-питания.-Воспользоваться-внешней-информацией-и-ответить-на-вопрос-—-в-каких-районах-Москвы-находятся-эти-улицы?" data-toc-modified-id="Построение-график-топ-10-улиц-по-количеству-объектов-общественного-питания.-Воспользоваться-внешней-информацией-и-ответить-на-вопрос-—-в-каких-районах-Москвы-находятся-эти-улицы?-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Построение график топ-10 улиц по количеству объектов общественного питания. Воспользоваться внешней информацией и ответить на вопрос — в каких районах Москвы находятся эти улицы?</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-3.7.0.1"><span class="toc-item-num">3.7.0.1&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li></ul></li></ul></li><li><span><a href="#Определение-числа-улиц-с-одним-объектом-общественного-питания.-В-каких-районах-Москвы-находятся-эти-улицы?" data-toc-modified-id="Определение-числа-улиц-с-одним-объектом-общественного-питания.-В-каких-районах-Москвы-находятся-эти-улицы?-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Определение числа улиц с одним объектом общественного питания. В каких районах Москвы находятся эти улицы?</a></span></li></ul></li><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Выводы:</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Ссылка-для-загрузки-презентации" data-toc-modified-id="Ссылка-для-загрузки-презентации-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Ссылка для загрузки презентации</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#🎓-Комментарий-от-студента-(синий)" data-toc-modified-id="🎓-Комментарий-от-студента-(синий)-6.0.0.1"><span class="toc-item-num">6.0.0.1&nbsp;&nbsp;</span>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# ### Контекст проекта

# %% [markdown]
# Мы с партнерами решили открыть небольшое кафе в Москве. У нас есть оригинальная идея- гостей должны обслуживать роботы. Мы считаем проект многообещающим, но он дорог в реализации. Поэтому мы решили обратиться к инвесторам.
#
# Их (инвесторов), как положено, интересует текущее положение дел на рынке. Например, сможем ли мы снискать популярность на долгое время, когда зеваки уже насмотрятся на роботов-официантов.
#
# Так получилось, что гуру аналитики в нашей группе единомышленников - это я. Поэтому меня попросили подготовить исследование рынка. У меня есть открытые данные о заведениях общественного питания города Москвы.

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Файл с данными для проекта: /datasets/rest_data.csv
#
# Таблица rest_data:
#
#     id — идентификатор объекта;
#     object_name — название объекта общественного питания;
#     chain — сетевой ресторан;
#     object_type — тип объекта общественного питания;
#     address — адрес;
#     number — количество посадочных мест.
#
# Кроме того, в проекте нужно будет использовать внешние данные о количестве заведений общественного питания по улицам Москвы. Эти данные мы возьмем на сайте Правительства Москвы data.mos.ru

# %% [markdown]
# ### Цели проекта

# %% [markdown]
# #### Загрузка данных и подготовка к анализу

# %% [markdown]
# Загрузить данные о заведениях общественного питания Москвы. Убедиться, что тип данных в каждой колонке — правильный, а также отсутствуют пропущенные значения и дубликаты. При необходимости обработать их.

# %% [markdown]
# #### Анализ данных
#
# Этапы:
#
#     1. Исследовать соотношение видов объектов общественного питания по количеству. Построить график.
#     2. Исследовать соотношение сетевых и несетевых заведений по количеству. Построить график.
#     3. Для какого вида объекта общественного питания характерно сетевое распространение?
#     4. Что характерно для сетевых заведений: много заведений с небольшим числом посадочных мест в каждом или мало заведений с большим количеством посадочных мест?
#     5. Для каждого вида объекта общественного питания описать среднее количество посадочных мест. Какой вид предоставляет в среднем самое большое количество посадочных мест? Построить графики.
#     6. Выделить в отдельный столбец информацию об улице из столбца address .
#     7. Построить график топ-10 улиц по количеству объектов общественного питания. Воспользоваться внешней информацией и ответить на вопрос — в каких районах Москвы находятся эти улицы?
#     8. Найти число улиц с одним объектом общественного питания. Воспользоваться внешней информацией и ответить на вопрос — в каких районах Москвы находятся эти улицы?

# %% [markdown]
# #### Общие выводы и рекомендации о:
#    - виде заведения
#    - количестве посадочных мест
#    - районе расположения
#    - перспективе развития сети

# %% [markdown]
# #### Подготовка презентации для инвестора
#
# Подготовить презентацию исследования для инвесторов. Для создания презентации использовать любой удобный инструмент, но отправить презентацию нужно обязательно в формате pdf. Приложить ссылку на презентацию в markdown-ячейке

# %% [markdown]
# ## Загрузка и подготовка данных

# %% [markdown]
# ### Импорт библиотек

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Открытие и исследование файлов данных

# %%
try:
   data = pd.read_csv('')
except:
   print ("Какая то ошибка")

# %%
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15366 entries, 0 to 15365
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           15366 non-null  int64
#  1   object_name  15366 non-null  object
#  2   chain        15366 non-null  object
#  3   object_type  15366 non-null  object
#  4   address      15366 non-null  object
#  5   number       15366 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 720.4+ KB
#        id             object_name chain object_type  \
# 0  151635                 СМЕТАНА   нет        кафе
# 1   77874                  Родник   нет        кафе
# 2   24309         Кафе «Академия»   нет        кафе
# 3   21894              ПИЦЦЕТОРИЯ    да        кафе
# 4  119365  Кафе «Вишневая метель»   нет        кафе
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# ...

# %% [markdown]
# Заголовки столбцов написаны корректно. Пропусков в данных не видно. Проверим наличие дубликатов

# %%
print ('Дубликатов в таблице:', data.duplicated().sum())
# Out:
# Дубликатов в таблице: 0

# %% [markdown]
# Проверим наличие дубликатов и аномальных значений в столбце object_type

# %%
print (len(data['object_type'].unique()))

print (data['object_type'].unique())
# Out:
# 9
# ['кафе' 'столовая' 'закусочная' 'предприятие быстрого обслуживания'
#  'ресторан' 'кафетерий' 'буфет' 'бар' 'магазин (отдел кулинарии)']

# %% [markdown]
# Дубликатов и вызывающих вопросы значений мы здесь не видим.

# %% [markdown]
# Попробуем оценить наличие дубликатов среди значений в столбце 'object_name'. В частности для сетевых заведений.

# %%
data['object_name']=data['object_name'].str.lower()

# %%
print(len (data[data['chain'] == 'да']['object_name'].unique()))
print(data[data['chain'] == 'да']['object_name'].unique())
# Out:
# 577
# ['пиццетория' 'брусника' 'алло пицца' 'суши wok' 'тануки' "домино'с пицца"
#  'готика' 'му-му' 'хлеб насущный' 'tajj mahal' 'данкин донатс'
#  'вареничная №1' 'шоколадница' 'теремок' 'хинкальная' 'шантимель'
#  'хинкальная city' 'кружка' 'суши вок' 'примавера' 'виктория'
#  'пиццерия «академия»' 'чебуречная ссср' 'макдоналдс' 'grand cru'
#  'чайхона №1' 'панчо пицца' 'kfc' 'сабвей' 'ресторан «якитория»'
#  'советские времена' 'кафе «андерсон»' 'кафе «subway»'
#  'ресторан «макдоналдс»' 'суши сет' 'шоколад' 'тирольские пироги'
#  'гамбринус' 'пицца фабрика' 'subway' 'кафе «якитория»' 'кафе «тануки»'
#  'сити пицца' 'кофе хаус'
#  'кулинарная лавка братьев караваевых братья караваевы' 'прайм'
#  'пицца экспресс' 'шоколадница кофе хаус' 'николай' 'якитория' 'магнолия'
#  'кофе с собой' 'джаганнат' 'волконский' 'moskalyan' 'гино-но-таки'
#  'тратория semplice' 'ньокки' 'хижина' 'додо пицца' 'крошка картошка'
#  'бургер кинг' 'папа джонс' 'кондитерская волконский'
# ...

# %% [markdown]
# Видим 577 уникальных значений. Избавляться здесь от дубликатов (а они есть) большая, кропотливая и ручная работа. С точки зрения задач, стоящих далее в исследовании она не не имеет смысла.

# %% [markdown]
# Предполагаем, что, если убрать поле id, мы можем найти дубликаты строк. Чтобы с ними разобраться, разделим датафрейм на два фрейма. В одном будут id, а во втором все остальные поля, затем удалим дубликаты во втором фрейме. И вновь объеденим таблицы (по вопросам исследования в этом нет необходимости, но чтобы максимально сохранить исходные фреймы мы это сделаем). Обеспечим возможность объединения за счет вынесения в отдельный столбец индексов.

# %%
data_r = data
data_r['index'] = data_r.index
data_r_id=data_r[['id','index']]
data_r_m=data_r.drop(['id','index'], axis=1)
print(data_r_m.head())
print(data_r_id.head())
# Out:
#               object_name chain object_type  \
# 0                 сметана   нет        кафе
# 1                  родник   нет        кафе
# 2         кафе «академия»   нет        кафе
# 3              пиццетория    да        кафе
# 4  кафе «вишневая метель»   нет        кафе
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50
#        id  index
# 0  151635      0
# 1   77874      1
# 2   24309      2
# 3   21894      3
# 4  119365      4

# %%
print ('Дубликатов в таблице:', data_r_m.duplicated().sum())
# Out:
# Дубликатов в таблице: 85

# %% [markdown]
# Удаляем их.

# %%
data_r_m  =data_r_m.drop_duplicates()
data_r_m['index'] = data_r_m.index
data_r_m.info()
print(data_r_m.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15281 entries, 0 to 15365
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   object_name  15281 non-null  object
#  1   chain        15281 non-null  object
#  2   object_type  15281 non-null  object
#  3   address      15281 non-null  object
#  4   number       15281 non-null  int64
#  5   index        15281 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 835.7+ KB
#                 object_name chain object_type  \
# 0                   сметана   нет        кафе
# 1                    родник   нет        кафе
# 2           кафе «академия»   нет        кафе
# 3                пиццетория    да        кафе
# 4    кафе «вишневая метель»   нет        кафе
# 5  стол. при гоу сош № 1051   нет    столовая
# 6                  брусника    да        кафе
# 7               буфет мтуси   нет    столовая
# 8               кпф семья-1   нет    столовая
# ...

# %% [markdown]
# Заново сливаем таблицы методом merge. И получаем датафрейм с удаленными дупликатами. С ним далее и работаем.

# %%
data_m=data_r_m.merge(data_r_id, on='index')
data_m.info()
data_m.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15281 entries, 0 to 15280
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   object_name  15281 non-null  object
#  1   chain        15281 non-null  object
#  2   object_type  15281 non-null  object
#  3   address      15281 non-null  object
#  4   number       15281 non-null  int64
#  5   index        15281 non-null  int64
#  6   id           15281 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 955.1+ KB
#               object_name chain object_type  \
# 0                 сметана   нет        кафе
# 1                  родник   нет        кафе
# 2         кафе «академия»   нет        кафе
# 3              пиццетория    да        кафе
# 4  кафе «вишневая метель»   нет        кафе
#
#                                              address  number  index      id
# 0         город Москва, улица Егора Абакумова, дом 9      48      0  151635
# ...

# %% [markdown]
# Для удобства обработки в столбце chain заменим значения да и нет на 1 и 0 (соотвественно)

# %%
data_m['chain'] = data_m['chain'].replace({'нет':'не сеть','да':'сеть'})
data_m.info()
data_m.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15281 entries, 0 to 15280
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   object_name  15281 non-null  object
#  1   chain        15281 non-null  object
#  2   object_type  15281 non-null  object
#  3   address      15281 non-null  object
#  4   number       15281 non-null  int64
#  5   index        15281 non-null  int64
#  6   id           15281 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 955.1+ KB
#               object_name    chain object_type  \
# 0                 сметана  не сеть        кафе
# 1                  родник  не сеть        кафе
# 2         кафе «академия»  не сеть        кафе
# 3              пиццетория     сеть        кафе
# 4  кафе «вишневая метель»  не сеть        кафе
#
#                                              address  number  index      id
# ...

# %% [markdown]
# Проверим наличие аномальных значений в столбце number. Для этого используем функции min и max

# %%
print ('максимальное значение в столбце number',data_m['number'].max())

print ('минимальное значение в столбце number',data_m['number'].min())
# Out:
# максимальное значение в столбце number 1700
# минимальное значение в столбце number 0

# %% [markdown]
# Заведения с 0 посадочных мест представить можно. Это могут быть кафе или буфеты, или что-то еще продают еду на вынос. А вот рестораны с 1700 посадочных мест вызывают вопросы. Нет, в мире существуют рестораны и с большим количеством посадочных мест (например, легендарный Хоф брой хаус в Мюнхене). Но применительно к Москве стоит все же проверить достоверность. Используем для этого гистограмму.

# %%
plt.figure(figsize = (16,6))
pd.Series(data_m['number']).hist(bins=20, range=(0,2000))
plt.title('Заведения общественного питания по количеству мест')
# Out:
# Text(0.5, 1.0, 'Заведения общественного питания по количеству мест')

# %%
data_mf=data_m.query('number<=300')
data_mf.reset_index()
data_mf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15158 entries, 0 to 15280
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   object_name  15158 non-null  object
#  1   chain        15158 non-null  object
#  2   object_type  15158 non-null  object
#  3   address      15158 non-null  object
#  4   number       15158 non-null  int64
#  5   index        15158 non-null  int64
#  6   id           15158 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 947.4+ KB

# %%
plt.figure(figsize = (16,6))
pd.Series(data_mf['number']).hist(bins=20, range=(0,300))
plt.title('Заведения общественного питания по количеству мест (300 и менее мест)')
# Out:
# Text(0.5, 1.0, 'Заведения общественного питания по количеству мест (300 и менее мест)')

# %% [markdown]
# В результате получения среза мы удалили 123 строки из 15281. Около 0,8%. Это допустимо. В целом в результате подготовки данных мы удалили 208 строк из 15366 (1,35%). Это незначительное количество. Далее будем анализировать данные из полученного среза.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Исследование соотношения видов объектов общественного питания по количеству.

# %% [markdown]
# Выполним группировку по типу данных, с использованием метода groupby.

# %%
data_obty = data_mf.groupby('object_type', as_index = False).agg({'number': 'count'}).sort_values(by='number', ascending=False)
data_obty=data_obty.rename(columns = {'number' : 'amount'})
data_obty.info()
data_obty.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 3 to 5
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   object_type  9 non-null      object
#  1   amount       9 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 216.0+ bytes
#                          object_type  amount
# 3                               кафе    6064
# 8                           столовая    2537
# 7                           ресторан    2218
# 6  предприятие быстрого обслуживания    1894
# 0                                бар     854
# 1                              буфет     575
# 4                          кафетерий     395
# 2                         закусочная     348
# 5          магазин (отдел кулинарии)     273

# %% [markdown]
# Построим график (столбчатую диаграмму).

# %%
plt.figure(figsize = (16,6))
sns.set_style('darkgrid')
(sns.barplot(y='object_type', x = 'amount', data=data_obty, color='royalblue').
 set(title = 'Cоотношение видов объектов общественного питания по количеству', xlabel = 'Количество',
      ylabel = 'Тип заведения')
)
# Out:
# [Text(0.5, 1.0, 'Cоотношение видов объектов общественного питания по количеству'),
#  Text(0.5, 0, 'Количество'),
#  Text(0, 0.5, 'Тип заведения')]

# %% [markdown]
# Построим такой же график в процентах. Посчитаем общее количество заведений всех типов.

# %%
object_total = data_obty['amount'].sum()
object_total
# Out:
# 15158

# %% [markdown]
# Добавим столбец с процентами и построим график.

# %%
data_obty['perc']=data_obty['amount']/object_total*100
data_obty= data_obty.round({'perc': 2})
data_obty.info()
data_obty.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 3 to 5
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   object_type  9 non-null      object
#  1   amount       9 non-null      int64
#  2   perc         9 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 588.0+ bytes
#                          object_type  amount   perc
# 3                               кафе    6064  40.01
# 8                           столовая    2537  16.74
# 7                           ресторан    2218  14.63
# 6  предприятие быстрого обслуживания    1894  12.50
# 0                                бар     854   5.63
# 1                              буфет     575   3.79
# 4                          кафетерий     395   2.61
# 2                         закусочная     348   2.30
# 5          магазин (отдел кулинарии)     273   1.80

# %%
plt.figure(figsize = (16,6))
sns.set_style('darkgrid')
(sns.barplot(y='object_type', x = 'perc', data=data_obty, color='royalblue')
 .set(title = 'Cоотношение видов объектов общественного питания по количеству в процентах', xlabel = 'Количество',
      ylabel = 'Тип заведения')
)
# Out:
# [Text(0.5, 1.0, 'Cоотношение видов объектов общественного питания по количеству в процентах'),
#  Text(0.5, 0, 'Количество'),
#  Text(0, 0.5, 'Тип заведения')]

# %% [markdown]
# Более 40% заведений составляют кафе, около 15% столовые и рестораны, около 13% предприятия быстрого обслуживания

# %% [markdown]
# ### Исследование соотношения сетевых и несетевых заведений по количеству.

# %% [markdown]
# Сгруппируем заведения по признаку "сеть" и "не сеть".

# %%
data_ch= data_mf.groupby('chain', as_index = False).agg({'number': 'count'}).sort_values(by='number', ascending=False)
data_ch=data_ch.rename(columns = {'number' : 'amount'})
data_ch.info()
data_ch.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   chain   2 non-null      object
#  1   amount  2 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 48.0+ bytes
#      chain  amount
# 0  не сеть   12213
# 1     сеть    2945

# %%
plt.figure(figsize = (16,6))
sns.set_style('darkgrid')
(sns.barplot( y='chain', x = 'amount',data=data_ch, color='royalblue')
 .set(title = 'Количество сетевых и не сетевых заведений', xlabel = 'Количество',
      ylabel = 'Вхождение в сеть')
)
# Out:
# [Text(0.5, 1.0, 'Количество сетевых и не сетевых заведений'),
#  Text(0.5, 0, 'Количество'),
#  Text(0, 0.5, 'Вхождение в сеть')]

# %%
data_ch_obty= (
    data_mf.groupby(['object_type','chain'], as_index = False).agg({'number': 'count'})
    .sort_values(by=['object_type', 'chain'], ascending=False)
)
data_ch_obty=data_ch_obty.rename(columns = {'number' : 'amount'})
data_ch_obty.info()
data_ch_obty.head(18)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 17 to 0
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   object_type  18 non-null     object
#  1   chain        18 non-null     object
#  2   amount       18 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 576.0+ bytes
#                           object_type    chain  amount
# 17                           столовая     сеть       3
# 16                           столовая  не сеть    2534
# 15                           ресторан     сеть     530
# 14                           ресторан  не сеть    1688
# 13  предприятие быстрого обслуживания     сеть     785
# 12  предприятие быстрого обслуживания  не сеть    1109
# 11          магазин (отдел кулинарии)     сеть      78
# 10          магазин (отдел кулинарии)  не сеть     195
# 9                           кафетерий     сеть      52
# ...

# %% [markdown]
# Преобладающим типом заведений являются не сетевые. По всем категориям.

# %%
plt.figure(figsize = (12,6))
(
    sns.barplot(x="amount", y="object_type", hue="chain", data=data_ch_obty)
    .set(title = 'Распространенность сетевых и несетевых заведений по количествам', xlabel = 'Количество',
      ylabel = 'Тип заведения')
)
# Out:
# [Text(0.5, 1.0, 'Распространенность сетевых и несетевых заведений по количествам'),
#  Text(0.5, 0, 'Количество'),
#  Text(0, 0.5, 'Тип заведения')]

# %% [markdown]
# Видим, что по всем типам заведений не сетевых заведений, больше, чем сетевых. Соответственно, нет возможности говорить о том, что какой-то тип заведений наиболее присущ именно сетевым.

# %% [markdown]
# ### Определение наиболее распространенного типа сетевых заведений

# %%
plt.figure(figsize = (16,6))
sns.set_style('darkgrid')
(sns.barplot( y='object_type', x = 'amount',data=data_ch_obty.query('chain=="сеть"').sort_values(by='amount', ascending=False), color='royalblue')
 .set(title = 'Количество сетевых заведений по типам', xlabel = 'Количество',
      ylabel = 'Вхождение в сеть')
)
# Out:
# [Text(0.5, 1.0, 'Количество сетевых заведений по типам'),
#  Text(0.5, 0, 'Количество'),
#  Text(0, 0.5, 'Вхождение в сеть')]

# %% [markdown]
# Среди сетевых заведений с большим отрывом лидируют кафе.

# %% [markdown]
# ### Что характерно для сетевых заведений: много заведений с небольшим числом посадочных мест в каждом или мало заведений с большим количеством посадочных мест?

# %% [markdown]
# Создадим срез данных по признаку "сеть". Построим графиг stripplot по количествам заведений по типам. А затем jointplot.

# %%
plt.figure(figsize = (10,6))
(
    sns.stripplot(data = data_mf.query('chain=="сеть"'),
                    x = "number", y = "object_type")
    .set(title = 'Количество посадочных мест по типам заведений', xlabel = 'Количество',
      ylabel = 'Тип заведения')
)
# Out:
# [Text(0.5, 1.0, 'Количество посадочных мест по типам заведений'),
#  Text(0.5, 0, 'Количество'),
#  Text(0, 0.5, 'Тип заведения')]

# %%
print ('Зависимость количества посадочных мест от типа заведения')
p=sns.jointplot(x='number', y='object_type', data=data_mf.query('chain=="сеть"'))
#p.fig.suptitle("Your title here")
p.set_axis_labels(xlabel='Количество посадочных мест', ylabel='Тип заведения')
p.fig.set_figwidth(13)
p.fig.set_figheight(7)
# Out:
# Зависимость количества посадочных мест от типа заведения

# %% [markdown]
# Достаточно много заведений с количеством посадочных мест менее 100 и мало распространены заведения с количеством мест более 200.

# %% [markdown]
# ###  Описание среднего количества посадочных мест для каждого вида объекта общественного питания. Какой вид предоставляет в среднем самое большое количество посадочных мест?

# %% [markdown]
# Сгруппируем данные методом groupby по типам заведений и признаку сеть/не сеть. И построим диаграмму среднего количества посадочных мест.

# %%
data_ch= (
    data_mf.groupby(['object_type','chain'], as_index = False)
          .agg({'number': 'mean'}).sort_values(by='number', ascending=False)
         )
#data_ch=data_ch.rename(columns = {'number' : 'amount'})
data_ch.info()
data_ch.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 16 to 10
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   object_type  18 non-null     object
#  1   chain        18 non-null     object
#  2   number       18 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 576.0+ bytes
#    object_type    chain      number
# 16    столовая  не сеть  124.771113
# 17    столовая     сеть  112.333333
# 15    ресторан     сеть   93.754717
# 14    ресторан  не сеть   83.082346
# 1          бар     сеть   53.027027

# %%
plt.figure(figsize = (12,6))
(
    sns.barplot(x="number", y="object_type", hue="chain", 
    data=data_mf.groupby(['object_type','chain'], as_index = False).agg({'number': 'mean'}).sort_values(by='number', ascending=False))
    .set(title = 'Среднее количество посадочных мест по типам заведний', xlabel = 'Среднее количество мест',
      ylabel = 'Тип заведения')
)
# Out:
# [Text(0.5, 1.0, 'Среднее количество посадочных мест по типам заведний'),
#  Text(0.5, 0, 'Среднее количество мест'),
#  Text(0, 0.5, 'Тип заведения')]

# %% [markdown]
# Наибольшее количество мест предоставляют столовые (и сетевые и не сетевые). В среднем около 120. Второе место по количеству мест занимают рестораны (сетевые и несетевые). В среднем около 90. Интересно отметить, что кафе предоставляют около 40 мест в среднем. Аналогичное количество мест представляют сетевые предприятия быстрого обслуживания. Тоже около 40.

# %% [markdown]
# ### Выделение в отдельный столбец информации об улице из столбца address .

# %% [markdown]
# Выделим наимениования улиц, разбив строковые значения в столбце address. Выделим нужный нам элемент по позиции. Вынесем его в отдельный столбец street.

# %%
data_mf['street'] = data_mf['address'].str.lower().str.split(",").apply(lambda x: x[1])
data_mf.info()
data_mf.reset_index()
data_mf.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15158 entries, 0 to 15280
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   object_name  15158 non-null  object
#  1   chain        15158 non-null  object
#  2   object_type  15158 non-null  object
#  3   address      15158 non-null  object
#  4   number       15158 non-null  int64
#  5   index        15158 non-null  int64
#  6   id           15158 non-null  int64
#  7   street       15158 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 1.0+ MB
# /tmp/ipykernel_63/1869471891.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ### Построение график топ-10 улиц по количеству объектов общественного питания. Воспользоваться внешней информацией и ответить на вопрос — в каких районах Москвы находятся эти улицы?

# %% [markdown]
# Импортируем внешний файл, полученный на сайте data.mos.ru

# %%
from io import BytesIO
import requests
spreadsheet_id = '1N2hnH_h7njFxL_Hc2ZXRK1dPVoYn1oWnvYNPtta1f8A'
file_name = 'https://docs.google.com/spreadsheets/d/{}/export?format=csv'.format(spreadsheet_id)
r = requests.get(file_name)
df = pd.read_csv(BytesIO(r.content))
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19709 entries, 0 to 19708
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19709 non-null  object
#  1   Name              19709 non-null  object
#  2   global_id         19709 non-null  object
#  3   IsNetObject       19709 non-null  object
#  4   OperatingCompany  3590 non-null   object
#  5   TypeObject        19709 non-null  object
#  6   AdmArea           19709 non-null  object
#  7   District          19709 non-null  object
#  8   Address           19709 non-null  object
#  9   PublicPhone       18791 non-null  object
#  10  SeatsCount        19709 non-null  object
#  11  SocialPrivileges  19709 non-null  object
#  12  Longitude_WGS84   19709 non-null  object
#  13  Latitude_WGS84    19709 non-null  object
#  14  geodata_center    964 non-null    object
#  15  geoarea           1 non-null      object
# dtypes: object(16)
# ...

# %% [markdown]
# Удалим явно лишние столбцы, которые нам точно не понадобятся.

# %%
df=(
    df.drop(['OperatingCompany', 'PublicPhone', 'SocialPrivileges', 'Longitude_WGS84',
             'Latitude_WGS84','geodata_center','geoarea','ID', 'global_id'], axis=1)
)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19709 entries, 0 to 19708
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         19709 non-null  object
#  1   IsNetObject  19709 non-null  object
#  2   TypeObject   19709 non-null  object
#  3   AdmArea      19709 non-null  object
#  4   District     19709 non-null  object
#  5   Address      19709 non-null  object
#  6   SeatsCount   19709 non-null  object
# dtypes: object(7)
# memory usage: 1.1+ MB
#                                                 Name       IsNetObject  \
# 0                                       Наименование  Является сетевым
# 1                                            СМЕТАНА               нет
# 2                                             Родник               нет
# 3                                    Кафе «Академия»               нет
# 4  ГБОУ «Школа № 1430 имени Героя Социалистическо...               нет
#
# ...

# %% [markdown]
# Создадим новый датафрейм, куда войдут нужные нам столбцы.

# %%
df1=df[['District','Address']]
df1.drop(index=[0], axis=0,inplace = True)
df1.reset_index(drop=True, inplace=True)
df1.info()
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19708 entries, 0 to 19707
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   District  19708 non-null  object
#  1   Address   19708 non-null  object
# dtypes: object(2)
# memory usage: 308.1+ KB
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#             District                                            Address
# 0  Ярославский район         город Москва, улица Егора Абакумова, дом 9
# 1    Таганский район  город Москва, улица Талалихина, дом 2/1, корпус 1
# 2    Таганский район  Российская Федерация, город Москва, внутригоро...
# ...

# %% [markdown]
# Выделим названия улиц в отдельный столбец, также, как делали выше, делением строки.

# %%
df1['street'] = df1['Address'].str.lower().str.split(",").apply(lambda x: x[1])
df1.info()
df1.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19708 entries, 0 to 19707
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   District  19708 non-null  object
#  1   Address   19708 non-null  object
#  2   street    19708 non-null  object
# dtypes: object(3)
# memory usage: 462.0+ KB
# /tmp/ipykernel_63/3353524040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['street'] = df1['Address'].str.lower().str.split(",").apply(lambda x: x[1])
#             District                                            Address  \
# 0  Ярославский район         город Москва, улица Егора Абакумова, дом 9
# 1    Таганский район  город Москва, улица Талалихина, дом 2/1, корпус 1
# ...

# %% [markdown]
# Создадим таблицу, в которой будут только нужные нам столбцы.

# %%
df2=df1[['District','street']]

df2.info()
df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19708 entries, 0 to 19707
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   District  19708 non-null  object
#  1   street    19708 non-null  object
# dtypes: object(2)
# memory usage: 308.1+ KB
#                    District                   street
# 0         Ярославский район    улица егора абакумова
# 1           Таганский район         улица талалихина
# 2           Таганский район             город москва
# 3           район Лианозово          угличская улица
# 4               район Арбат   переулок сивцев вражек
# ...                     ...                      ...
# 19703     Даниловский район   улица серпуховский вал
# 19704     Пресненский район             город москва
# 19705       Бутырский район             город москва
# 19706  Красносельский район             город москва
# 19707   район Замоскворечье             город москва
#
# ...

# %% [markdown]
# Удалим дубликаты из таблицы с улицами и районами.

# %%
print ('Дубликатов в таблице:', df2.duplicated().sum())
# Out:
# Дубликатов в таблице: 17411

# %%
df2 =df2.drop_duplicates()
df2.info()
df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2297 entries, 0 to 19698
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   District  2297 non-null   object
#  1   street    2297 non-null   object
# dtypes: object(2)
# memory usage: 53.8+ KB
#                 District                                          street
# 0      Ярославский район                           улица егора абакумова
# 1        Таганский район                                улица талалихина
# 2        Таганский район                                    город москва
# 3        район Лианозово                                 угличская улица
# 4            район Арбат                          переулок сивцев вражек
# ...                  ...                                             ...
# 19613   район Ивановское                                 прокатная улица
# 19614    район Хамовники                             поселение сосенское
# ...

# %% [markdown]
# Создадим таблицу количеством ресторанов по улицам.

# %%
data_str=(
    data_mf.groupby(['street'], as_index = False).agg({'object_name': 'count'})
    .sort_values(by='object_name', ascending=False).reset_index()
)
data_str.rename(columns = {'object_name' : 'rest_amount'}, inplace = True)
data_str.info()
data_str.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1897 entries, 0 to 1896
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        1897 non-null   int64
#  1   street       1897 non-null   object
#  2   rest_amount  1897 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 44.6+ KB
#     index                    street  rest_amount
# 0     486          город зеленоград          231
# 1    1120             проспект мира          202
# 2    1124         профсоюзная улица          181
# 3     746    ленинградский проспект          169
# 4    1081    пресненская набережная          165
# 5     417          варшавское шоссе          159
# 6     749        ленинский проспект          146
# 7    1070       поселение сосенское          137
# 8    1117      проспект вернадского          126
# 9     737      кутузовский проспект          112
# 10    662           каширское шоссе          109
# ...

# %% [markdown]
# Так, как в ТЗ просят определить ТОП-10 УЛИЦ!, то отбрасываем строки 'город зеленоград' и 'поселение сосенское'

# %%
data_str.drop(index = [0,7],axis = 0,inplace = True)
data_str.drop(labels = 'index',axis = 1,inplace = True)

data_str_top=data_str.query('rest_amount>=108')
data_str_top
# Out:
#                      street  rest_amount
# 1             проспект мира          202
# 2         профсоюзная улица          181
# 3    ленинградский проспект          169
# 4    пресненская набережная          165
# 5          варшавское шоссе          159
# 6        ленинский проспект          146
# 8      проспект вернадского          126
# 9      кутузовский проспект          112
# 10          каширское шоссе          109
# 11     кировоградская улица          108

# %%
plt.figure(figsize = (16,6))
sns.set_style('darkgrid')
(sns.barplot(y='street', x = 'rest_amount', data=data_str_top, color='royalblue')
 .set(title = 'ТОП-10 улиц Москвы по количеству заведений', xlabel = 'Количество заведений',
      ylabel = 'Улица/шоссе/проспект')
)
# Out:
# [Text(0.5, 1.0, 'ТОП-10 улиц Москвы по количеству заведений'),
#  Text(0.5, 0, 'Количество заведений'),
#  Text(0, 0.5, 'Улица/шоссе/проспект')]

# %% [markdown]
# Объеденим таблицу с районами и с ТОПом улиц

# %%
str_top_dist=data_str_top.merge(df2, on='street')
str_top_dist.info()
str_top_dist
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46 entries, 0 to 45
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   street       46 non-null     object
#  1   rest_amount  46 non-null     int64
#  2   District     46 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.4+ KB
#                      street  rest_amount                         District
# 0             проспект мира          202                  Мещанский район
# 1             проспект мира          202               Останкинский район
# 2             проспект мира          202               Алексеевский район
# 3             проспект мира          202                   район Свиблово
# 4             проспект мира          202                  район Ростокино
# 5         профсоюзная улица          181                  район Черёмушки
# 6         профсоюзная улица          181                район Тёплый Стан
# ...

# %% [markdown]
# В таблице данные о том, в каких районах находятся улицы из ТОП-10 по количеству ресторанов. Речь идет о самых длинных улицах Москвы, поэтому районов довольно много. К тому же все эти улицы - выездные магистрали из города. Исключение - пресненская набережная - это Москва-Сити.

# %% [markdown]
# ### Определение числа улиц с одним объектом общественного питания. В каких районах Москвы находятся эти улицы?

# %%
one_rest=data_str.query('rest_amount==1')
one_rest.reset_index(drop=True, inplace=True)
one_rest
# Out:
#                    street  rest_amount
# 0          улица рудневой            1
# 1        нагорный бульвар            1
# 2        напольный проезд            1
# 3          улица рословка            1
# 4     3-й дорожный проезд            1
# ..                    ...          ...
# 581       линейный проезд            1
# 582    лонгиновская улица            1
# 583      будайский проезд            1
# 584       будайская улица            1
# 585       яхромская улица            1
#
# [586 rows x 2 columns]

# %%
str_one_dist=one_rest.merge(df2, on='street',how='left')
str_one_dist.info()
str_one_dist
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600 entries, 0 to 599
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   street       600 non-null    object
#  1   rest_amount  600 non-null    int64
#  2   District     411 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 18.8+ KB
#                    street  rest_amount               District
# 0          улица рудневой            1     Бабушкинский район
# 1        нагорный бульвар            1         район Котловка
# 2        напольный проезд            1       район Ивановское
# 3          улица рословка            1           район Митино
# 4     3-й дорожный проезд            1  район Чертаново Южное
# ..                    ...          ...                    ...
# 595       линейный проезд            1    Тимирязевский район
# 596    лонгиновская улица            1                    NaN
# ...

# %%
str_one_dist = str_one_dist.fillna('Нет района')
str_one_dist.info()
str_one_dist
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600 entries, 0 to 599
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   street       600 non-null    object
#  1   rest_amount  600 non-null    int64
#  2   District     600 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 18.8+ KB
#                    street  rest_amount               District
# 0          улица рудневой            1     Бабушкинский район
# 1        нагорный бульвар            1         район Котловка
# 2        напольный проезд            1       район Ивановское
# 3          улица рословка            1           район Митино
# 4     3-й дорожный проезд            1  район Чертаново Южное
# ..                    ...          ...                    ...
# 595       линейный проезд            1    Тимирязевский район
# 596    лонгиновская улица            1             Нет района
# ...

# %%
one_dist=(
    str_one_dist.groupby(['District'], as_index = False).agg({'rest_amount': 'count'})
    .sort_values(by='rest_amount', ascending=False).reset_index()
)
one_dist.head(30)
# Out:
#     index                 District  rest_amount
# 0      17               Нет района          189
# 1      24          Таганский район           21
# 2      89          район Хамовники           19
# 3       3          Басманный район           19
# 4      25           Тверской район           18
# 5      82         район Сокольники           12
# 6      21        Пресненский район           10
# 7      14          Мещанский район           10
# 8      33              район Арбат           10
# 9      15          Можайский район            9
# 10     94       район Южное Бутово            9
# 11     44      район Замоскворечье            9
# 12     81     район Соколиная Гора            9
# 13     12     Красносельский район            8
# 14     37        район Богородское            7
# 15     26      Тимирязевский район            7
# 16     34           район Аэропорт            7
# 17     90  район Хорошёво-Мнёвники            7
# 18     93             район Щукино            7
# ...

# %% [markdown]
# Среди районов, где улицы с одним заведением, либо окраины, либо самый центр (там есть очень короткие улицы и переулки (буквально несколько десятков метров)

# %% [markdown]
# ## Выводы:

# %% [markdown]
# 1. В ходе исследования была проведена предварительная обработка данных. В результате были удалены дубликаты и аномальные значения. Были удалены 208 строк из 15366 (1,35%).
# 2. Наиболее распространенным типом заведения по сетевым и не сетевым заведениям является кафе (около 40% всех заведений). Далее следуют столовая, ресторан и предприятия быстрого обслуживания (около 15%).
# 3. Преобладают несетевые заведения. Их больше, чем в пять раз, чем сетевых. 12 000 заведений.
# 4. Среди сетевых заведений Достаточно много заведений с количеством посадочных мест менее 100 и мало распространены заведения с количеством мест более 200.
# 5. Наибольшее количество посадочных мест в столовых. Но этот тип заведения не подходит для нашей концепции. У ресторанов количество посадочных мест около 80 (и для сетевых, и для несетевых заведений). Около 40 посадочных мест (бар, буфет, кафе, предприятия быстрого обслуживания).
# 6. Наибольшее количество ресторанов различных типов находятся на выездных магистралях. На момент открытия стоит рассматривать их, как локацию. Окраины и сплальные районы не интересны.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Предлагается открыть сеть из трех-четырех кафе на Проспекте Мира, Профсоюзной улице, Варшавском шоссе, Ленинградском проспекте. Количество посадочных мест - 30

# %% [markdown]
# ## Ссылка для загрузки презентации

# %% [markdown]
# https://disk.yandex.ru/i/hsiKSUJVyt4wHQ
